# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10, 6)

# %%
data = np.fromfile("/tmp/psk.raw", dtype=np.uint8)
data.shape
# Out:
# (581632,)

# %%
plt.plot(data)
plt.xlim(115000, 120000)
plt.ylim(-.2, 1.2)
# Out:
# (-0.2, 1.2)

# %%
msg = np.unpackbits(np.array([0, 0] + [ord(c) for c in "Hello"], dtype=np.uint8))
plt.plot(np.repeat(msg, 10))
plt.ylim(-.2, 1.2)
# Out:
# (-0.2, 1.2)
